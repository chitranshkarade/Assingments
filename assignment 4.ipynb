# %%
1. What exactly is []?

# %%
[] This is an empty list.

# %%
2. In a list of values stored in a variable called spam, how would you assign the value "hello" as the
third value? (Assume [2, 4, 6, 8, 10] are in spam.)
Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.

# %%
spam = [2,4, 6, 8, 10]
print("previous list -> ", spam)
spam[2] = "hello"
print("new list -> ", spam)
spam = ['a', 'b', 'c', 'd']
print(spam)
# Out:
# previous list ->  [2, 4, 6, 8, 10]
# new list ->  [2, 4, 'hello', 8, 10]
# ['a', 'b', 'c', 'd']

# %%
3. What is the value of spam[int(int('3' * 2) / 11)]?
Ans. spam = ['a', 'b', 'c', 'd']
 In the following list we are going to run -> spam[int(int('3' * 2) / 11)]
    operation will work as follows.
    ('3' * 2) -> "33"
    int("33") -> 33 # as an integer value
    33/11 -> 3
    spam[3] will be value at index 3 that is 'd'

# %%
spam[int(int('3' * 2) / 11)]
# Out:
# 'd'

# %%
4. What is the value of spam[-1]?

# %%
spam[-1] #it will be the last value of the list
# Out:
# 'd'

# %%
5. What is the value of spam[:2]?

# %%
spam[:2]  # is "a" , "b"
# Out:
# ['a', 'b']

# %%
Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions

6. What is the value of bacon.index('cat')?
Ans.

# %%
bacon = [3.14, 'cat', 11, 'cat', True]

# %%
bacon.index('cat')
# Out:
# 1

# %%
7. How does bacon.append(99) change the look of the list value in bacon?
Ans.

# %%
bacon.append(99) # it will add "99" at the end of the list
print(bacon)
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %%
8. How does bacon.remove('cat') change the look of the list in bacon?
Ans.

# %%
bacon.remove("cat") # it will remove the element named "cat" from the list
print(bacon)
# Out:
# [3.14, 11, True, 99]

# %%
9. What are the list concatenation and list replication operators?
Ans. List concatenation operator is " + " and list replication operator is " * "
for eg ->

# %%
a = [1,2,3,4]
b = [5,6,7,8]
c = a+b  #it will add two list 
d = a*2 # and it will replicate list
print("List concatenation -> " ,c) 
print("List replication -> " ,d)
# Out:
# List concatenation ->  [1, 2, 3, 4, 5, 6, 7, 8]
# List replication ->  [1, 2, 3, 4, 1, 2, 3, 4]

# %%
10. What is difference between the list methods append() and insert()?
Ans. In a list , append method appends the given element to the end of the list and insert method accepts 
     two arguments, index at which the element needs to be inserted and the object to insert.

# %%
11. What are the two methods for removing items from a list?
Ans. The two methods for removing items from a list are :-
    1. remove()
    2. pop()

# %%
12. Describe how list values and string values are identical.
Ans. While list is a collection of values in Python, string is a collection of characters.
     Both list and strings are iterable in Python and a for loop can be used around a list or string object 
     to iterate through each element in the list/string.

# %%
13. What's the difference between tuples and lists?
Ans.Tuples are immutable where as lists in Python are mutable. So once created, the items inside a tuple cannot be changed ,
    while in a list we can .

# %%
14. How do you type a tuple value that only contains the integer 42?
Ans.

# %%
t = tuple([42])
print(t)
# Out:
# (42,)

# %%
15. How do you get a list value's tuple form? How do you get a tuple value's list form?
Ans .By using the keyword . "tuple" and "list"

# %%
a = [1,2,3]
a = tuple(a)
print(type(a)) # tuple
b = list(a)
print(type(b)) # list
# Out:
# <class 'tuple'>
# <class 'list'>

# %%
16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?
Ans.

# %%
var = [1,2,3]
print(var)
print(id(var))
[1, 2, 3]
1359003680000   # They contain references to the list values

# %%
17. How do you distinguish between copy.copy() and copy.deepcopy()?

# %%
Ans.copy() create reference to original object. If you change copied object - you change the original object. 
    deepcopy() creates new object and does real copying of original object to new one. Changing new deepcopied 
    object doesn't affect original object.
